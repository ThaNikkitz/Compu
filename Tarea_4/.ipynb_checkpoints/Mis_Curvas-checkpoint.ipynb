# %%
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy

# %%
a = numpy.loadtxt('oli.txt')

# %%
b = []
c = []
for i in a:
    b.append(i[0])
    c.append(i[2])

# %%
plt.plot(b, c)
