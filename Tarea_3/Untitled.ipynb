# %%
import numpy
from matplotlib import pyplot
# %matplotlib inline 

a = numpy.linspace(0,212.8,111)
results = []
with open('resultados.txt') as inputfile:
    for line in inputfile:
        results.append(line.strip().split(','))

# %%
pyplot.plot(a,results);
